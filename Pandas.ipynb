# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Display Options

# %%
# to show maximum number of columns and rows of dataframe
pd.set_option('display.max_rows', 20)
pd.set_option('display.max_columns', 8)

# %% [markdown]
# # Making Dataframe

# %%
people={
        "Ranking": [np.NaN, "One", "Two", "Three", "Four", "Five", "Six", "Seven", "Eight","Nine"],
        "First":[np.NaN, "ali","Missing","ali","Anum","talha","hassan", "usman", "haris","hania"],
        "Last" : [np.NaN, "haider","Abida", "farooq", "ali", "khalid", np.NAN, "qadir", "rauf","altaf"],
        "Email" : [np.NaN,"alihaider@yahoo.com", "Abida@dreamhost.com", "alifarooq@yahoo.com", "anumali@bing.com", "talhakhalid@gmail.com","hassanraza@gmail.com", "usmanqadir@yahoo.com", "harisrauf@gmail.com","haniaaltaf@webmail.com"],
        "Age" : [np.NaN, 30,"Missing", 22, 34, np.NaN, 38, 23, 27, 40],
        "Gender" : [np.NaN, "Male","Female","Male","Female","Male", "Male", "Male", "Male", "Female"],
        "Salary" : [np.NaN, 50000, "None", 100000, 43000, 75000, "None", 38000, 44000, 87000],
        "Country" : [np.NaN, "pakistan", "india", "pakistan", "uzbikistan","india", "tajakistan", "india", "US", "pakistan"]
    
}

# %%
df= pd.DataFrame(people)
df
# Out:
#    Ranking    First    Last                   Email      Age  Gender  Salary  \
# 0      NaN      NaN     NaN                     NaN      NaN     NaN     NaN
# 1      One      ali  haider     alihaider@yahoo.com       30    Male   50000
# 2      Two  Missing   Abida     Abida@dreamhost.com  Missing  Female    None
# 3    Three      ali  farooq     alifarooq@yahoo.com       22    Male  100000
# ..     ...      ...     ...                     ...      ...     ...     ...
# 6      Six   hassan     NaN    hassanraza@gmail.com       38    Male    None
# 7    Seven    usman   qadir    usmanqadir@yahoo.com       23    Male   38000
# 8    Eight    haris    rauf     harisrauf@gmail.com       27    Male   44000
# 9     Nine    hania   altaf  haniaaltaf@webmail.com       40  Female   87000
#
#        Country
# 0          NaN
# 1     pakistan
# 2        india
# 3     pakistan
# ..         ...
# 6   tajakistan
# 7        india
# 8           US
# 9     pakistan
#
# [10 rows x 8 columns]

# %% [markdown]
# # Missing Handling values

# %%
#droping whole row if having all the values set to NAN

df.dropna(axis="columns", how="any")
df.dropna(axis="index", how="any", subset=["Ranking"])
df.dropna(axis="index", how="all", inplace=True)

# %%
df
# Out:
#   Ranking    First    Last                   Email      Age  Gender  Salary  \
# 1     One      ali  haider     alihaider@yahoo.com       30    Male   50000
# 2     Two  Missing   Abida     Abida@dreamhost.com  Missing  Female    None
# 3   Three      ali  farooq     alifarooq@yahoo.com       22    Male  100000
# 4    Four     Anum     ali        anumali@bing.com       34  Female   43000
# 5    Five    talha  khalid   talhakhalid@gmail.com      NaN    Male   75000
# 6     Six   hassan     NaN    hassanraza@gmail.com       38    Male    None
# 7   Seven    usman   qadir    usmanqadir@yahoo.com       23    Male   38000
# 8   Eight    haris    rauf     harisrauf@gmail.com       27    Male   44000
# 9    Nine    hania   altaf  haniaaltaf@webmail.com       40  Female   87000
#
#       Country
# 1    pakistan
# 2       india
# 3    pakistan
# 4  uzbikistan
# 5       india
# 6  tajakistan
# 7       india
# 8          US
# 9    pakistan

# %%
# handling custom missing values in dataframe
df.replace("Missing", np.NaN, inplace=True)
df.replace("None", np.NaN, inplace=True)

# %%
df
# Out:
#   Ranking   First    Last                   Email   Age  Gender    Salary  \
# 1     One     ali  haider     alihaider@yahoo.com  30.0    Male   50000.0
# 2     Two     NaN   Abida     Abida@dreamhost.com   NaN  Female       NaN
# 3   Three     ali  farooq     alifarooq@yahoo.com  22.0    Male  100000.0
# 4    Four    Anum     ali        anumali@bing.com  34.0  Female   43000.0
# 5    Five   talha  khalid   talhakhalid@gmail.com   NaN    Male   75000.0
# 6     Six  hassan     NaN    hassanraza@gmail.com  38.0    Male       NaN
# 7   Seven   usman   qadir    usmanqadir@yahoo.com  23.0    Male   38000.0
# 8   Eight   haris    rauf     harisrauf@gmail.com  27.0    Male   44000.0
# 9    Nine   hania   altaf  haniaaltaf@webmail.com  40.0  Female   87000.0
#
#       Country
# 1    pakistan
# 2       india
# 3    pakistan
# 4  uzbikistan
# 5       india
# 6  tajakistan
# 7       india
# 8          US
# 9    pakistan

# %%
# checking any missing value
df.isnull().any()
# Out:
# Ranking    False
# First       True
# Last        True
# Email      False
# Age         True
# Gender     False
# Salary      True
# Country    False
# dtype: bool

# %%
# back filling for First column inside dataframe
df["First"]=df["First"].bfill(axis ='rows')

# forward filling for Last column inside dataframe
df["Last"]=df["Last"].bfill(axis ='rows')

# %%
# filling missing age by their mean
df["Age"]=df["Age"].fillna(df["Age"].mean())

# %%
# filling missing slary by their median
df["Salary"]=df["Salary"].fillna(df["Salary"].median())

# %%
df
# Out:
#   Ranking   First    Last                   Email        Age  Gender  \
# 1     One     ali  haider     alihaider@yahoo.com  30.000000    Male
# 2     Two     ali   Abida     Abida@dreamhost.com  30.571429  Female
# 3   Three     ali  farooq     alifarooq@yahoo.com  22.000000    Male
# 4    Four    Anum     ali        anumali@bing.com  34.000000  Female
# 5    Five   talha  khalid   talhakhalid@gmail.com  30.571429    Male
# 6     Six  hassan   qadir    hassanraza@gmail.com  38.000000    Male
# 7   Seven   usman   qadir    usmanqadir@yahoo.com  23.000000    Male
# 8   Eight   haris    rauf     harisrauf@gmail.com  27.000000    Male
# 9    Nine   hania   altaf  haniaaltaf@webmail.com  40.000000  Female
#
#      Salary     Country
# 1   50000.0    pakistan
# 2   50000.0       india
# 3  100000.0    pakistan
# 4   43000.0  uzbikistan
# 5   75000.0       india
# 6   50000.0  tajakistan
# 7   38000.0       india
# 8   44000.0          US
# 9   87000.0    pakistan

# %% [markdown]
# # Reading & Writing Dataframe

# %%
# writing dataframe to csv format
df.to_csv("./peopledataframe.csv", index=False)

# %%
# reading dataframe
df=pd.read_csv("./peopledataframe.csv")

# %% [markdown]
# # Head and Tail

# %%
# to show top lines of dataframe
df.head(5)
# Out:
#   Ranking  First    Last                  Email        Age  Gender    Salary  \
# 0     One    ali  haider    alihaider@yahoo.com  30.000000    Male   50000.0
# 1     Two    ali   Abida    Abida@dreamhost.com  30.571429  Female   50000.0
# 2   Three    ali  farooq    alifarooq@yahoo.com  22.000000    Male  100000.0
# 3    Four   Anum     ali       anumali@bing.com  34.000000  Female   43000.0
# 4    Five  talha  khalid  talhakhalid@gmail.com  30.571429    Male   75000.0
#
#       Country
# 0    pakistan
# 1       india
# 2    pakistan
# 3  uzbikistan
# 4       india

# %%
# to show bottom lines of dataframe
df.tail(5)
# Out:
#   Ranking   First    Last                   Email        Age  Gender   Salary  \
# 4    Five   talha  khalid   talhakhalid@gmail.com  30.571429    Male  75000.0
# 5     Six  hassan   qadir    hassanraza@gmail.com  38.000000    Male  50000.0
# 6   Seven   usman   qadir    usmanqadir@yahoo.com  23.000000    Male  38000.0
# 7   Eight   haris    rauf     harisrauf@gmail.com  27.000000    Male  44000.0
# 8    Nine   hania   altaf  haniaaltaf@webmail.com  40.000000  Female  87000.0
#
#       Country
# 4       india
# 5  tajakistan
# 6       india
# 7          US
# 8    pakistan

# %% [markdown]
# # Extracting meaningful about Dataframe

# %%
# to check the shape of dataframe
df.shape
# Out:
# (9, 8)

# %%
# statistical information about the dataframe
df.describe()
# Out:
#              Age         Salary
# count   9.000000       9.000000
# mean   30.571429   59666.666667
# std     6.120808   22028.390772
# min    22.000000   38000.000000
# 25%    27.000000   44000.000000
# 50%    30.571429   50000.000000
# 75%    34.000000   75000.000000
# max    40.000000  100000.000000

# %%
# to check the datatypes of columns
df.dtypes
# Out:
# Ranking     object
# First       object
# Last        object
# Email       object
# Age        float64
# Gender      object
# Salary     float64
# Country     object
# dtype: object

# %%
# to check information about the columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ranking  9 non-null      object
#  1   First    9 non-null      object
#  2   Last     9 non-null      object
#  3   Email    9 non-null      object
#  4   Age      9 non-null      float64
#  5   Gender   9 non-null      object
#  6   Salary   9 non-null      float64
#  7   Country  9 non-null      object
# dtypes: float64(2), object(6)
# memory usage: 704.0+ bytes

# %% [markdown]
# # Setting & Resetting index

# %%
# set the index of dataframe by unique item
df.set_index("Ranking", inplace=True)
df
# Out:
#           First    Last                   Email        Age  Gender    Salary  \
# Ranking
# One         ali  haider     alihaider@yahoo.com  30.000000    Male   50000.0
# Two         ali   Abida     Abida@dreamhost.com  30.571429  Female   50000.0
# Three       ali  farooq     alifarooq@yahoo.com  22.000000    Male  100000.0
# Four       Anum     ali        anumali@bing.com  34.000000  Female   43000.0
# Five      talha  khalid   talhakhalid@gmail.com  30.571429    Male   75000.0
# Six      hassan   qadir    hassanraza@gmail.com  38.000000    Male   50000.0
# Seven     usman   qadir    usmanqadir@yahoo.com  23.000000    Male   38000.0
# Eight     haris    rauf     harisrauf@gmail.com  27.000000    Male   44000.0
# Nine      hania   altaf  haniaaltaf@webmail.com  40.000000  Female   87000.0
#
#             Country
# Ranking
# One        pakistan
# Two           india
# Three      pakistan
# Four     uzbikistan
# Five          india
# Six      tajakistan
# Seven         india
# Eight            US
# Nine       pakistan

# %%
#reseting the index
df.reset_index()
df
# Out:
#           First    Last                   Email        Age  Gender    Salary  \
# Ranking
# One         ali  haider     alihaider@yahoo.com  30.000000    Male   50000.0
# Two         ali   Abida     Abida@dreamhost.com  30.571429  Female   50000.0
# Three       ali  farooq     alifarooq@yahoo.com  22.000000    Male  100000.0
# Four       Anum     ali        anumali@bing.com  34.000000  Female   43000.0
# Five      talha  khalid   talhakhalid@gmail.com  30.571429    Male   75000.0
# Six      hassan   qadir    hassanraza@gmail.com  38.000000    Male   50000.0
# Seven     usman   qadir    usmanqadir@yahoo.com  23.000000    Male   38000.0
# Eight     haris    rauf     harisrauf@gmail.com  27.000000    Male   44000.0
# Nine      hania   altaf  haniaaltaf@webmail.com  40.000000  Female   87000.0
#
#             Country
# Ranking
# One        pakistan
# Two           india
# Three      pakistan
# Four     uzbikistan
# Five          india
# Six      tajakistan
# Seven         india
# Eight            US
# Nine       pakistan

# %% [markdown]
# # Accessing columns of Dataframe

# %%
df[['First', 'Age']]
# Out:
#           First        Age
# Ranking
# One         ali  30.000000
# Two         ali  30.571429
# Three       ali  22.000000
# Four       Anum  34.000000
# Five      talha  30.571429
# Six      hassan  38.000000
# Seven     usman  23.000000
# Eight     haris  27.000000
# Nine      hania  40.000000

# %% [markdown]
# # Accessing rows of Dataframe

# %%
#access the row or data point by index
df.iloc[0:3]
# Out:
#         First    Last                Email        Age  Gender    Salary  \
# Ranking
# One       ali  haider  alihaider@yahoo.com  30.000000    Male   50000.0
# Two       ali   Abida  Abida@dreamhost.com  30.571429  Female   50000.0
# Three     ali  farooq  alifarooq@yahoo.com  22.000000    Male  100000.0
#
#           Country
# Ranking
# One      pakistan
# Two         india
# Three    pakistan

# %%
#access the row or data point by index id
df.loc['One':'Three',["First","Age"]]
# Out:
#         First        Age
# Ranking
# One       ali  30.000000
# Two       ali  30.571429
# Three     ali  22.000000

# %% [markdown]
# # Distributional Ratio of the column

# %%
# value_count() function will give you frequency of the items

df['Gender'].value_counts()
# Out:
# Male      6
# Female    3
# Name: Gender, dtype: int64

# %%
#count() function will give you the total number of enteries in a column or series
df["Gender"].count()
# Out:
# 9

# %% [markdown]
# # Filtering Rows

# %%
#persons having salary over 50000

custom_filter=df["Salary"]>=50000

df.loc[custom_filter]
# Out:
#           First    Last                   Email        Age  Gender    Salary  \
# Ranking
# One         ali  haider     alihaider@yahoo.com  30.000000    Male   50000.0
# Two         ali   Abida     Abida@dreamhost.com  30.571429  Female   50000.0
# Three       ali  farooq     alifarooq@yahoo.com  22.000000    Male  100000.0
# Five      talha  khalid   talhakhalid@gmail.com  30.571429    Male   75000.0
# Six      hassan   qadir    hassanraza@gmail.com  38.000000    Male   50000.0
# Nine      hania   altaf  haniaaltaf@webmail.com  40.000000  Female   87000.0
#
#             Country
# Ranking
# One        pakistan
# Two           india
# Three      pakistan
# Five          india
# Six      tajakistan
# Nine       pakistan

# %%
#persons having first name or last name as ali

custom_filter= (df["First"]=="ali") | (df["Last"]=="ali")

df.loc[custom_filter]
# Out:
#         First    Last                Email        Age  Gender    Salary  \
# Ranking
# One       ali  haider  alihaider@yahoo.com  30.000000    Male   50000.0
# Two       ali   Abida  Abida@dreamhost.com  30.571429  Female   50000.0
# Three     ali  farooq  alifarooq@yahoo.com  22.000000    Male  100000.0
# Four     Anum     ali     anumali@bing.com  34.000000  Female   43000.0
#
#             Country
# Ranking
# One        pakistan
# Two           india
# Three      pakistan
# Four     uzbikistan

# %%
# person living in a country name ending with 'istan'
custom_filter = df["Country"].str.contains("istan", na=False)
df.loc[custom_filter]
# Out:
#           First    Last                   Email   Age  Gender    Salary  \
# Ranking
# One         ali  haider     alihaider@yahoo.com  30.0    Male   50000.0
# Three       ali  farooq     alifarooq@yahoo.com  22.0    Male  100000.0
# Four       Anum     ali        anumali@bing.com  34.0  Female   43000.0
# Six      hassan   qadir    hassanraza@gmail.com  38.0    Male   50000.0
# Nine      hania   altaf  haniaaltaf@webmail.com  40.0  Female   87000.0
#
#             Country
# Ranking
# One        pakistan
# Three      pakistan
# Four     uzbikistan
# Six      tajakistan
# Nine       pakistan

# %% [markdown]
# # Updating columns

# %%
#updating all the columns

df.columns=["First_Name", "Last_Name", "Email", "Age", "Gender", "Salary", "Country"]
df
# Out:
#         First_Name Last_Name                   Email        Age  Gender  \
# Ranking
# One            ali    haider     alihaider@yahoo.com  30.000000    Male
# Two            ali     Abida     Abida@dreamhost.com  30.571429  Female
# Three          ali    farooq     alifarooq@yahoo.com  22.000000    Male
# Four          Anum       ali        anumali@bing.com  34.000000  Female
# Five         talha    khalid   talhakhalid@gmail.com  30.571429    Male
# Six         hassan     qadir    hassanraza@gmail.com  38.000000    Male
# Seven        usman     qadir    usmanqadir@yahoo.com  23.000000    Male
# Eight        haris      rauf     harisrauf@gmail.com  27.000000    Male
# Nine         hania     altaf  haniaaltaf@webmail.com  40.000000  Female
#
#            Salary     Country
# Ranking
# One       50000.0    pakistan
# Two       50000.0       india
# Three    100000.0    pakistan
# Four      43000.0  uzbikistan
# Five      75000.0       india
# Six       50000.0  tajakistan
# Seven     38000.0       india
# Eight     44000.0          US
# Nine      87000.0    pakistan

# %%
#updating specific columns
df.rename(columns={"First_Name" : "First", "Last_Name" : "Last" }, inplace=True)
df
# Out:
#           First    Last                   Email        Age  Gender    Salary  \
# Ranking
# One         ali  haider     alihaider@yahoo.com  30.000000    Male   50000.0
# Two         ali   Abida     Abida@dreamhost.com  30.571429  Female   50000.0
# Three       ali  farooq     alifarooq@yahoo.com  22.000000    Male  100000.0
# Four       Anum     ali        anumali@bing.com  34.000000  Female   43000.0
# Five      talha  khalid   talhakhalid@gmail.com  30.571429    Male   75000.0
# Six      hassan   qadir    hassanraza@gmail.com  38.000000    Male   50000.0
# Seven     usman   qadir    usmanqadir@yahoo.com  23.000000    Male   38000.0
# Eight     haris    rauf     harisrauf@gmail.com  27.000000    Male   44000.0
# Nine      hania   altaf  haniaaltaf@webmail.com  40.000000  Female   87000.0
#
#             Country
# Ranking
# One        pakistan
# Two           india
# Three      pakistan
# Four     uzbikistan
# Five          india
# Six      tajakistan
# Seven         india
# Eight            US
# Nine       pakistan

# %% [markdown]
# # Updating Rows

# %%
# set the salary of indians to double

custom_filter=df["Country"]=="india"

df.loc[custom_filter,"Salary"]=df.loc[custom_filter,"Salary"]*2

df.loc[custom_filter]
# Out:
#          First    Last                  Email        Age  Gender    Salary  \
# Ranking
# Two        ali   Abida    Abida@dreamhost.com  30.571429  Female  100000.0
# Five     talha  khalid  talhakhalid@gmail.com  30.571429    Male  150000.0
# Seven    usman   qadir   usmanqadir@yahoo.com  23.000000    Male   76000.0
#
#         Country
# Ranking
# Two       india
# Five      india
# Seven     india

# %% [markdown]
# ### Apply

# %%
# apply metthod will apply the function to the specific column or series only

# %%
#capital case letters for country

df["Country"] = df["Country"].apply(lambda x: x.upper())

# %%
#find mailing address for the every email

# %%
def mail_service_finder(email_adddress):
    """
    returns the mailing host of the email for every user
    """
    
    return email_adddress.split(".")[0].split("@")[-1]

# %%
df["Mailing_Host"] = df["Email"].apply(mail_service_finder)
df
# Out:
#           First    Last                   Email        Age  Gender    Salary  \
# Ranking
# One         ali  haider     alihaider@yahoo.com  30.000000    Male   50000.0
# Two         ali   Abida     Abida@dreamhost.com  30.571429  Female  100000.0
# Three       ali  farooq     alifarooq@yahoo.com  22.000000    Male  100000.0
# Four       Anum     ali        anumali@bing.com  34.000000  Female   43000.0
# Five      talha  khalid   talhakhalid@gmail.com  30.571429    Male  150000.0
# Six      hassan   qadir    hassanraza@gmail.com  38.000000    Male   50000.0
# Seven     usman   qadir    usmanqadir@yahoo.com  23.000000    Male   76000.0
# Eight     haris    rauf     harisrauf@gmail.com  27.000000    Male   44000.0
# Nine      hania   altaf  haniaaltaf@webmail.com  40.000000  Female   87000.0
#
#             Country Mailing_Host
# Ranking
# One        PAKISTAN        yahoo
# Two           INDIA    dreamhost
# Three      PAKISTAN        yahoo
# Four     UZBIKISTAN         bing
# Five          INDIA        gmail
# Six      TAJAKISTAN        gmail
# Seven         INDIA        yahoo
# Eight            US        gmail
# Nine       PAKISTAN      webmail

# %% [markdown]
# ### Map

# %%
# Used for substituting each value in a Series with another value, but return Nan for non matching value

# %%
#replace Male with 'M' and Female with 'F'


df["Gender"] = df["Gender"].map({"Male" : "M", "Female": "F"})
df
# Out:
#           First    Last                   Email        Age Gender    Salary  \
# Ranking
# One         ali  haider     alihaider@yahoo.com  30.000000      M   50000.0
# Two         ali   Abida     Abida@dreamhost.com  30.571429      F  100000.0
# Three       ali  farooq     alifarooq@yahoo.com  22.000000      M  100000.0
# Four       Anum     ali        anumali@bing.com  34.000000      F   43000.0
# Five      talha  khalid   talhakhalid@gmail.com  30.571429      M  150000.0
# Six      hassan   qadir    hassanraza@gmail.com  38.000000      M   50000.0
# Seven     usman   qadir    usmanqadir@yahoo.com  23.000000      M   76000.0
# Eight     haris    rauf     harisrauf@gmail.com  27.000000      M   44000.0
# Nine      hania   altaf  haniaaltaf@webmail.com  40.000000      F   87000.0
#
#             Country Mailing_Host
# Ranking
# One        PAKISTAN        yahoo
# Two           INDIA    dreamhost
# Three      PAKISTAN        yahoo
# Four     UZBIKISTAN         bing
# Five          INDIA        gmail
# Six      TAJAKISTAN        gmail
# Seven         INDIA        yahoo
# Eight            US        gmail
# Nine       PAKISTAN      webmail

# %% [markdown]
# ### Replace

# %%
# Used for substituting each value in a Series with another value, and keep non-matching value un-changed rather than NaN.

# %%
#change US to United-States 

df["Country"] = df["Country"].replace({"US" : "United-States"})
df
# Out:
#           First    Last                   Email        Age Gender    Salary  \
# Ranking
# One         ali  haider     alihaider@yahoo.com  30.000000      M   50000.0
# Two         ali   Abida     Abida@dreamhost.com  30.571429      F  100000.0
# Three       ali  farooq     alifarooq@yahoo.com  22.000000      M  100000.0
# Four       Anum     ali        anumali@bing.com  34.000000      F   43000.0
# Five      talha  khalid   talhakhalid@gmail.com  30.571429      M  150000.0
# Six      hassan   qadir    hassanraza@gmail.com  38.000000      M   50000.0
# Seven     usman   qadir    usmanqadir@yahoo.com  23.000000      M   76000.0
# Eight     haris    rauf     harisrauf@gmail.com  27.000000      M   44000.0
# Nine      hania   altaf  haniaaltaf@webmail.com  40.000000      F   87000.0
#
#                Country Mailing_Host
# Ranking
# One           PAKISTAN        yahoo
# Two              INDIA    dreamhost
# Three         PAKISTAN        yahoo
# Four        UZBIKISTAN         bing
# Five             INDIA        gmail
# Six         TAJAKISTAN        gmail
# Seven            INDIA        yahoo
# Eight    United-States        gmail
# Nine          PAKISTAN      webmail

# %% [markdown]
# # Dropping Columns

# %%
#lets add a dumpy column firts
df["Email_length"]=df["Email"].apply(lambda x: len(x))
df
# Out:
#           First    Last                   Email        Age  ...    Salary  \
# Ranking                                                     ...
# One         ali  haider     alihaider@yahoo.com  30.000000  ...   50000.0
# Two         ali   Abida     Abida@dreamhost.com  30.571429  ...  100000.0
# Three       ali  farooq     alifarooq@yahoo.com  22.000000  ...  100000.0
# Four       Anum     ali        anumali@bing.com  34.000000  ...   43000.0
# Five      talha  khalid   talhakhalid@gmail.com  30.571429  ...  150000.0
# Six      hassan   qadir    hassanraza@gmail.com  38.000000  ...   50000.0
# Seven     usman   qadir    usmanqadir@yahoo.com  23.000000  ...   76000.0
# Eight     haris    rauf     harisrauf@gmail.com  27.000000  ...   44000.0
# Nine      hania   altaf  haniaaltaf@webmail.com  40.000000  ...   87000.0
#
#                Country Mailing_Host Email_length
# Ranking
# One           PAKISTAN        yahoo           19
# Two              INDIA    dreamhost           19
# Three         PAKISTAN        yahoo           19
# Four        UZBIKISTAN         bing           16
# Five             INDIA        gmail           21
# Six         TAJAKISTAN        gmail           20
# Seven            INDIA        yahoo           20
# Eight    United-States        gmail           19
# Nine          PAKISTAN      webmail           22
#
# [9 rows x 9 columns]

# %% [markdown]
# ### Delete columns

# %%
#drop the column named Email_length
df.drop(columns=["Email_length"], inplace=True)
df
# Out:
#           First    Last                   Email        Age Gender    Salary  \
# Ranking
# One         ali  haider     alihaider@yahoo.com  30.000000      M   50000.0
# Two         ali   Abida     Abida@dreamhost.com  30.571429      F  100000.0
# Three       ali  farooq     alifarooq@yahoo.com  22.000000      M  100000.0
# Four       Anum     ali        anumali@bing.com  34.000000      F   43000.0
# Five      talha  khalid   talhakhalid@gmail.com  30.571429      M  150000.0
# Six      hassan   qadir    hassanraza@gmail.com  38.000000      M   50000.0
# Seven     usman   qadir    usmanqadir@yahoo.com  23.000000      M   76000.0
# Eight     haris    rauf     harisrauf@gmail.com  27.000000      M   44000.0
# Nine      hania   altaf  haniaaltaf@webmail.com  40.000000      F   87000.0
#
#                Country Mailing_Host
# Ranking
# One           PAKISTAN        yahoo
# Two              INDIA    dreamhost
# Three         PAKISTAN        yahoo
# Four        UZBIKISTAN         bing
# Five             INDIA        gmail
# Six         TAJAKISTAN        gmail
# Seven            INDIA        yahoo
# Eight    United-States        gmail
# Nine          PAKISTAN      webmail

# %% [markdown]
# ### Delete rows

# %%
#drop the user having mailing address set to bing

custom_filter= df["Mailing_Host"]=="bing"
df.drop(index= df.loc[custom_filter].index, inplace=True)
df
# Out:
#           First    Last                   Email        Age Gender    Salary  \
# Ranking
# One         ali  haider     alihaider@yahoo.com  30.000000      M   50000.0
# Two         ali   Abida     Abida@dreamhost.com  30.571429      F  100000.0
# Three       ali  farooq     alifarooq@yahoo.com  22.000000      M  100000.0
# Five      talha  khalid   talhakhalid@gmail.com  30.571429      M  150000.0
# Six      hassan   qadir    hassanraza@gmail.com  38.000000      M   50000.0
# Seven     usman   qadir    usmanqadir@yahoo.com  23.000000      M   76000.0
# Eight     haris    rauf     harisrauf@gmail.com  27.000000      M   44000.0
# Nine      hania   altaf  haniaaltaf@webmail.com  40.000000      F   87000.0
#
#                Country Mailing_Host
# Ranking
# One           PAKISTAN        yahoo
# Two              INDIA    dreamhost
# Three         PAKISTAN        yahoo
# Five             INDIA        gmail
# Six         TAJAKISTAN        gmail
# Seven            INDIA        yahoo
# Eight    United-States        gmail
# Nine          PAKISTAN      webmail

# %% [markdown]
# # Sorting values

# %%
# sort by max to min salary

df.sort_values(by="Salary", ascending=False)
# Out:
#           First    Last                   Email        Age Gender    Salary  \
# Ranking
# Five      talha  khalid   talhakhalid@gmail.com  30.571429      M  150000.0
# Two         ali   Abida     Abida@dreamhost.com  30.571429      F  100000.0
# Three       ali  farooq     alifarooq@yahoo.com  22.000000      M  100000.0
# Nine      hania   altaf  haniaaltaf@webmail.com  40.000000      F   87000.0
# Seven     usman   qadir    usmanqadir@yahoo.com  23.000000      M   76000.0
# One         ali  haider     alihaider@yahoo.com  30.000000      M   50000.0
# Six      hassan   qadir    hassanraza@gmail.com  38.000000      M   50000.0
# Eight     haris    rauf     harisrauf@gmail.com  27.000000      M   44000.0
#
#                Country Mailing_Host
# Ranking
# Five             INDIA        gmail
# Two              INDIA    dreamhost
# Three         PAKISTAN        yahoo
# Nine          PAKISTAN      webmail
# Seven            INDIA        yahoo
# One           PAKISTAN        yahoo
# Six         TAJAKISTAN        gmail
# Eight    United-States        gmail

# %%
# sort by salary and then by age

df.sort_values(by=["Salary", "Age"], ascending=[True, False])
# Out:
#           First    Last                   Email        Age Gender    Salary  \
# Ranking
# Eight     haris    rauf     harisrauf@gmail.com  27.000000      M   44000.0
# Six      hassan   qadir    hassanraza@gmail.com  38.000000      M   50000.0
# One         ali  haider     alihaider@yahoo.com  30.000000      M   50000.0
# Seven     usman   qadir    usmanqadir@yahoo.com  23.000000      M   76000.0
# Nine      hania   altaf  haniaaltaf@webmail.com  40.000000      F   87000.0
# Two         ali   Abida     Abida@dreamhost.com  30.571429      F  100000.0
# Three       ali  farooq     alifarooq@yahoo.com  22.000000      M  100000.0
# Five      talha  khalid   talhakhalid@gmail.com  30.571429      M  150000.0
#
#                Country Mailing_Host
# Ranking
# Eight    United-States        gmail
# Six         TAJAKISTAN        gmail
# One           PAKISTAN        yahoo
# Seven            INDIA        yahoo
# Nine          PAKISTAN      webmail
# Two              INDIA    dreamhost
# Three         PAKISTAN        yahoo
# Five             INDIA        gmail

# %%
# extract the top five salaries

df["Salary"].nlargest(5)
# Out:
# Ranking
# Five     150000.0
# Two      100000.0
# Three    100000.0
# Nine      87000.0
# Seven     76000.0
# Name: Salary, dtype: float64

# %% [markdown]
# # Groupby

# %%
# Groupby allows you to split the dataframe, apply some function over it and combining the results of it

# %%
# groupby functions

country_group = df.groupby(['Country'])

country_group.first()
# Out:
#                 First    Last                 Email        Age Gender  \
# Country
# INDIA             ali   Abida   Abida@dreamhost.com  30.571429      F
# PAKISTAN          ali  haider   alihaider@yahoo.com  30.000000      M
# TAJAKISTAN     hassan   qadir  hassanraza@gmail.com  38.000000      M
# United-States   haris    rauf   harisrauf@gmail.com  27.000000      M
#
#                  Salary Mailing_Host
# Country
# INDIA          100000.0    dreamhost
# PAKISTAN        50000.0        yahoo
# TAJAKISTAN      50000.0        gmail
# United-States   44000.0        gmail

# %%
# finding mailing address for pakistan 
country_group.get_group("PAKISTAN")["Mailing_Host"].value_counts()
# Out:
# yahoo      2
# webmail    1
# Name: Mailing_Host, dtype: int64

# %% [markdown]
# # Aggregation or agg

# %%
# apply multiple function over the columns at once

# %%
# finding maximum, minimum, mean, median of salary
df["Salary"].agg(["min","max","median", "mean"])
# Out:
# min        44000.0
# max       150000.0
# median     81500.0
# mean       82125.0
# Name: Salary, dtype: float64

# %%
# aggplying agg on different columns differently
df.agg({"Salary": "mean", "Age":"median"})
# Out:
# Salary    82125.000000
# Age          30.285714
# dtype: float64

# %% [markdown]
# # Groupy and agg

# %%
# maximum and minimum salary in pakistan

country_group = df.groupby(['Country'])

country_group["Salary"].agg(["max", "min"]).loc["PAKISTAN"]
# Out:
# max    100000.0
# min     50000.0
# Name: PAKISTAN, dtype: float64

# %%
# how many people from each country who are having mailing host as gmail

country_group = df.groupby(['Country'])

country_group["Mailing_Host"].apply(lambda x: x.str.contains("gmail").sum())
# Out:
# Country
# INDIA            1
# PAKISTAN         0
# TAJAKISTAN       1
# United-States    1
# Name: Mailing_Host, dtype: int64

# %%
# how many people having age over 20 and salary over 70000 from INDIA

country_group = df.groupby(["Country"])
indian_group = country_group.get_group("INDIA")
custom_filter = (indian_group["Salary"] > 70000) & (indian_group["Age"]>20.0)
indian_group[custom_filter]
# Out:
#          First    Last                  Email        Age Gender    Salary  \
# Ranking
# Two        ali   Abida    Abida@dreamhost.com  30.571429      F  100000.0
# Five     talha  khalid  talhakhalid@gmail.com  30.571429      M  150000.0
# Seven    usman   qadir   usmanqadir@yahoo.com  23.000000      M   76000.0
#
#         Country Mailing_Host
# Ranking
# Two       INDIA    dreamhost
# Five      INDIA        gmail
# Seven     INDIA        yahoo

# %% [markdown]
# # Temporal Data

# %%
from datetime import datetime

# %%
d_parser= lambda x: datetime.strptime(x,"%Y-%m-%d %I-%p")
df=pd.read_csv("./ETH_1h.csv",parse_dates=["Date"],date_parser=d_parser)
df.head(5)
# Out:
#                  Date  Symbol    Open    High     Low   Close      Volume
# 0 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71

# %%
# converting the Date column to datetime format if not imported in parsed way

df['Date']=pd.to_datetime(df['Date'], format="%Y-%m-%d %I-%p")
df.head(5)
# Out:
#                  Date  Symbol    Open    High     Low   Close      Volume
# 0 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71

# %%
#finding the day of each date
df["DayOfWeek"]=df["Date"].dt.day_name()

# %%
# finding total number of days inside the dataframe

df["Date"].max()-df["Date"].min()
# Out:
# Timedelta('986 days 09:00:00')

# %%
# setting the index to the Date column
df.set_index("Date",inplace=True)

# %%
df.head(5)
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
#
#                     DayOfWeek
# Date
# 2020-03-13 20:00:00    Friday
# 2020-03-13 19:00:00    Friday
# 2020-03-13 18:00:00    Friday
# 2020-03-13 17:00:00    Friday
# 2020-03-13 16:00:00    Friday

# %%
# getting data from From Feb 2019 to Feb 2020
custom_filter = (df.index >="2019-02-01") & (df.index <="2020-02-01")
df.loc[custom_filter].head(5)

# OR

df["2019-02-01":"2020-02-01"].head(5)
# Out:
#                      Symbol    Open    High     Low   Close     Volume  \
# Date
# 2020-02-01 23:00:00  ETHUSD  182.95  184.20  182.85  183.50  382805.96
# 2020-02-01 22:00:00  ETHUSD  182.54  183.41  182.42  182.95  306650.06
# 2020-02-01 21:00:00  ETHUSD  183.08  183.55  182.06  182.54  283654.97
# 2020-02-01 20:00:00  ETHUSD  182.47  183.39  182.05  183.08  603486.90
# 2020-02-01 19:00:00  ETHUSD  183.29  183.32  182.11  182.47  345791.52
#
#                     DayOfWeek
# Date
# 2020-02-01 23:00:00  Saturday
# 2020-02-01 22:00:00  Saturday
# 2020-02-01 21:00:00  Saturday
# 2020-02-01 20:00:00  Saturday
# 2020-02-01 19:00:00  Saturday

# %%
# find maximum and minimum for month, day and week basis

df.resample("D")["High"].max()
df.resample("W")["High"].max()
df.resample("M")["High"].max()

df.resample("D")["Low"].min()
df.resample("W")["Low"].min()
df.resample("M")["Low"].min()
# Out:
# Date
# 2017-07-31    130.26
# 2017-08-31    200.82
# 2017-09-30    202.25
# 2017-10-31    275.46
# 2017-11-30    278.88
#                ...
# 2019-11-30    131.80
# 2019-12-31    116.25
# 2020-01-31    125.52
# 2020-02-29    178.98
# 2020-03-31     90.00
# Freq: M, Name: Low, Length: 33, dtype: float64

# %%
# aggregate on it

df.resample("Y").agg({"Close" : "mean", "Low" : "min", "High" : "max", "Volume" : "sum"})
# Out:
#                  Close     Low     High        Volume
# Date
# 2017-12-31  351.966277  130.26   875.00  1.298966e+10
# 2018-12-31  480.932120   80.60  1419.96  2.394412e+10
# 2019-12-31  180.752030  100.15   364.49  8.199368e+09
# 2020-12-31  197.568759   90.00   290.00  2.476100e+09
